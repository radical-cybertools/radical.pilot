# %%
# %pylab inline

import os
import matplotlib.pyplot   as plt
import pandas              as pd
import pprint              as pp

import radical.utils       as ru
import radical.pilot       as rp
import radical.pilot.utils as rpu

pd.set_option('display.height',      500)
pd.set_option('display.max_rows',    500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width',       200)

os.environ['RADICAL_PILOT_VERBOSE'] = 'ERROR'
os.environ['SAGA_VERBOSE']          = 'ERROR'
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# 2015-08-24 03:45:50,275: radical.pilot       : MainProcess                     : MainThread     : INFO    : python.interpreter   version: 2.7.5+ (default, Sep 17 2013, 15:31:50) [GCC 4.8.1]
# 2015-08-24 03:45:50,276: radical.pilot       : MainProcess                     : MainThread     : INFO    : radical.pilot        version: v0.34-494-g3c40c94@feature-agent_split
# height has been deprecated.

# %%
# NOTE: this cell needs quite some time to execute...  Like, minutes.

sid   = "rp.session.cameo.merzky.016671.0001"
src   = "/home/merzky/saga/radical.pilot.prof"

profiles   = rpu.fetch_profiles(sid=sid, src=src, tgt='/tmp/')
profile    = rpu.combine_profiles (profiles)
frame      = rpu.prof2frame(profile)
sf, pf, uf = rpu.split_frame(frame)
# Out:
# fetching '/home/merzky/saga/radical.pilot.prof/rp.session.cameo.merzky.016671.0001.prof' to '/tmp/'.
# Session: rp.session.cameo.merzky.016671.0001
# Number of pilots in session: 1
# Processing pilot 'pilot.0000'
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentExecutingComponent_SHELL.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentExecutingWatcher_SHELL.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentHeartbeatWorker.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentStagingInputComponent.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentStagingOutputComponent.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentUpdateWorker.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.AgentWorker.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//agent.0.SchedulerContinuous.0.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//bootstrap_3.prof' to '/tmp/'.
# fetching 'file://localhost/home/merzky/radical.pilot.sandbox/rp.session.cameo.merzky.016671.0001-pilot.0000//launch_method.prof.prof' to '/tmp/'.

# %%
rpu.add_states(uf)
rpu.add_info(uf)

uf3 = uf[uf['uid'] == 'unit.000003']
uf3
# uf3[pd.notnull(uf3['state_from'])]
# Out:
#           event                                             msg                                               name                      state     time          uid entity cloned  \
# 7       advance                                          create     rp.session.cameo.merzky.016671.0001:MainThread                        New   1.0142  unit.000003   unit  False
# 12      advance                                                     rp.session.cameo.merzky.016671.0001:MainThread                Unscheduled   1.0384  unit.000003   unit  False
# 42      advance                                                       rp.session.cameo.merzky.016671.0001:Thread-1        PendingInputStaging  20.1876  unit.000003   unit  False
# 53      advance                                                  rp.session.cameo.merzky.016671.0001:InputFileT...               StagingInput  21.0511  unit.000003   unit  False
# 55      advance                                                  rp.session.cameo.merzky.016671.0001:InputFileT...   AgentStagingInputPending  22.0059  unit.000003   unit  False
# 69      publish                                                                   agent.0.AgentWorker.0:MainThread   AgentStagingInputPending  22.0747  unit.000003   unit  False
# 70          put     queue.agent_staging_input_queue.input.23743                   agent.0.AgentWorker.0:MainThread   AgentStagingInputPending  22.0753  unit.000003   unit  False
# 81          get    queue.agent_staging_input_queue.output.23769    agent.0.AgentStagingInputComponent.0:MainThread   AgentStagingInputPending  22.0772  unit.000003   unit  False
# 85   work start                                                    agent.0.AgentStagingInputComponent.0:MainThread   AgentStagingInputPending  22.0776  unit.000003   unit  False
# 86      advance                                                    agent.0.AgentStagingInputComponent.0:MainThread          AgentStagingInput  22.0777  unit.000003   unit  False
# 87      publish                                                    agent.0.AgentStagingInputComponent.0:MainThread          AgentStagingInput  22.0778  unit.000003   unit  False
# 92   unit mkdir                                                    agent.0.AgentStagingInputComponent.0:MainThread          AgentStagingInput  22.0783  unit.000003   unit  False
# 93          log                         toward agent scheduling    agent.0.AgentStagingInputComponent.0:MainThread          AgentStagingInput  22.0784  unit.000003   unit  False
# 94      advance                                                    agent.0.AgentStagingInputComponent.0:MainThread          AllocatingPending  22.0784  unit.000003   unit  False
# 95      publish                                                    agent.0.AgentStagingInputComponent.0:MainThread          AllocatingPending  22.0785  unit.000003   unit  False
# 97          put        queue.agent_scheduling_queue.input.23769    agent.0.AgentStagingInputComponent.0:MainThread          AllocatingPending  22.0786  unit.000003   unit  False
# 98   work done                                                     agent.0.AgentStagingInputComponent.0:MainThread          AllocatingPending  22.0787  unit.000003   unit  False
# 99          get   update unit state to AgentStagingInputPending               agent.0.AgentUpdateWorker.0:Thread-2          AllocatingPending  22.0799  unit.000003   unit  False
# 110        bulk               bulked (AgentStagingInputPending)               agent.0.AgentUpdateWorker.0:Thread-2          AllocatingPending  22.0809  unit.000003   unit  False
# 125         get       queue.agent_scheduling_queue.output.23770           agent.0.SchedulerContinuous.0:MainThread          AllocatingPending  22.0845  unit.000003   unit  False
# 126  work start                                                           agent.0.SchedulerContinuous.0:MainThread          AllocatingPending  22.0850  unit.000003   unit  False
# 127     advance                                                           agent.0.SchedulerContinuous.0:MainThread                 Allocating  22.0851  unit.000003   unit  False
# 128     publish                                                           agent.0.SchedulerContinuous.0:MainThread                 Allocating  22.0852  unit.000003   unit  False
# 133    schedule                                       allocated           agent.0.SchedulerContinuous.0:MainThread                 Allocating  22.0854  unit.000003   unit  False
# 136    schedule                            allocation succeeded           agent.0.SchedulerContinuous.0:MainThread                 Allocating  22.0856  unit.000003   unit  False
# 137     advance                                                           agent.0.SchedulerContinuous.0:MainThread           ExecutingPending  22.0856  unit.000003   unit  False
# 141     publish                                                           agent.0.SchedulerContinuous.0:MainThread           ExecutingPending  22.0857  unit.000003   unit  False
# 143         put         queue.agent_executing_queue.input.23770           agent.0.SchedulerContinuous.0:MainThread           ExecutingPending  22.0859  unit.000003   unit  False
# 144  work done                                                            agent.0.SchedulerContinuous.0:MainThread           ExecutingPending  22.0859  unit.000003   unit  False
# 201         get          update unit state to AgentStagingInput               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.0933  unit.000003   unit  False
# 205        bulk                      bulked (AgentStagingInput)               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.0934  unit.000003   unit  False
# 215         get          update unit state to AllocatingPending               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.0960  unit.000003   unit  False
# 216        bulk                      bulked (AllocatingPending)               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.0962  unit.000003   unit  False
# 251         get                 update unit state to Allocating               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.1044  unit.000003   unit  False
# 252        bulk                             bulked (Allocating)               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.1045  unit.000003   unit  False
# 253         get           update unit state to ExecutingPending               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.1055  unit.000003   unit  False
# 254        bulk                       bulked (ExecutingPending)               agent.0.AgentUpdateWorker.0:Thread-2           ExecutingPending  22.1055  unit.000003   unit  False
# 336      update   unit update pushed (AgentStagingInputPending)             agent.0.AgentUpdateWorker.0:MainThread           ExecutingPending  23.1812  unit.000003   unit  False
# 343      update          unit update pushed (AgentStagingInput)             agent.0.AgentUpdateWorker.0:MainThread           ExecutingPending  23.1812  unit.000003   unit  False
# 344      update          unit update pushed (AllocatingPending)             agent.0.AgentUpdateWorker.0:MainThread           ExecutingPending  23.1813  unit.000003   unit  False
# 347      update                 unit update pushed (Allocating)             agent.0.AgentUpdateWorker.0:MainThread           ExecutingPending  23.1813  unit.000003   unit  False
# 348      update           unit update pushed (ExecutingPending)             agent.0.AgentUpdateWorker.0:MainThread           ExecutingPending  23.1813  unit.000003   unit  False
# 376         pre                                           start   agent.0.AgentStagingOutputComponent.0:MainThread           ExecutingPending  26.3537  unit.000003   unit  False
# 378         get        queue.agent_executing_queue.output.23771   agent.0.AgentExecutingWatcher_SHELL.0:MainThread           ExecutingPending  27.2154  unit.000003   unit  False
# 379  work start                                                   agent.0.AgentExecutingWatcher_SHELL.0:MainThread           ExecutingPending  27.2157  unit.000003   unit  False
# 380     advance                                                   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2157  unit.000003   unit  False
# 381     publish                                                   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2159  unit.000003   unit  False
# 382        exec                                     unit launch   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2161  unit.000003   unit  False
# 383       spawn                                      unit spawn   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2161  unit.000003   unit  False
# 384     command                       launch script constructed   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2163  unit.000003   unit  False
# 385         get                  update unit state to Executing               agent.0.AgentUpdateWorker.0:Thread-2                  Executing  27.2183  unit.000003   unit  False
# 386        bulk                              bulked (Executing)               agent.0.AgentUpdateWorker.0:Thread-2                  Executing  27.2184  unit.000003   unit  False
# 388      update                  unit update pushed (Executing)               agent.0.AgentUpdateWorker.0:Thread-2                  Executing  27.2193  unit.000003   unit  False
# 389       spawn                          spawning passed to pty   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.3328  unit.000003   unit  False
# 390         put                          to watcher (Executing)   agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.3329  unit.000003   unit  False
# 391  work done                                                    agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.3329  unit.000003   unit  False
# 401         pre                                            stop   agent.0.AgentStagingOutputComponent.0:MainThread                  Executing  27.3537  unit.000003   unit  False
# 492        post                                           start   agent.0.AgentStagingOutputComponent.0:MainThread                  Executing  28.3537  unit.000003   unit  False
# 500        post                                            stop   agent.0.AgentStagingOutputComponent.0:MainThread                  Executing  29.3537  unit.000003   unit  False
# 509         get                      ExecWatcher picked up unit      agent.0.AgentExecutingWatcher_SHELL.0:Watcher                  Executing  30.3458  unit.000003   unit  False
# 510       final                             execution succeeded      agent.0.AgentExecutingWatcher_SHELL.0:Watcher                  Executing  30.3460  unit.000003   unit  False
# 511     advance                                                      agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.3461  unit.000003   unit  False
# 512     publish                                                      agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.3463  unit.000003   unit  False
# 513         put    queue.agent_staging_output_queue.input.23771      agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.3466  unit.000003   unit  False
# 514  unschedule                                                             agent.0.SchedulerContinuous.0:Thread-2  AgentStagingOutputPending  30.3496  unit.000003   unit  False
# 515         get  update unit state to AgentStagingOutputPending               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3502  unit.000003   unit  False
# 516        bulk              bulked (AgentStagingOutputPending)               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3503  unit.000003   unit  False
# 518      update  unit update pushed (AgentStagingOutputPending)               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3513  unit.000003   unit  False
# 528         get         update unit state to AgentStagingOutput               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3661  unit.000003   unit  False
# 529        bulk                     bulked (AgentStagingOutput)               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3662  unit.000003   unit  False
# 530         get       update unit state to PendingOutputStaging               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3672  unit.000003   unit  False
# 531        bulk                   bulked (PendingOutputStaging)               agent.0.AgentUpdateWorker.0:Thread-2  AgentStagingOutputPending  30.3673  unit.000003   unit  False
# 532         get   queue.agent_staging_output_queue.output.23772   agent.0.AgentStagingOutputComponent.0:MainThread  AgentStagingOutputPending  30.3673  unit.000003   unit  False
# 533  work start                                                   agent.0.AgentStagingOutputComponent.0:MainThread  AgentStagingOutputPending  30.3677  unit.000003   unit  False
# 534     advance                                                   agent.0.AgentStagingOutputComponent.0:MainThread         AgentStagingOutput  30.3677  unit.000003   unit  False
# 535     publish                                                   agent.0.AgentStagingOutputComponent.0:MainThread         AgentStagingOutput  30.3679  unit.000003   unit  False
# 536     advance                                                   agent.0.AgentStagingOutputComponent.0:MainThread       PendingOutputStaging  30.3682  unit.000003   unit  False
# 537     publish                                                   agent.0.AgentStagingOutputComponent.0:MainThread       PendingOutputStaging  30.3683  unit.000003   unit  False
# 538  work done                                                    agent.0.AgentStagingOutputComponent.0:MainThread       PendingOutputStaging  30.3683  unit.000003   unit  False
# 687      update         unit update pushed (AgentStagingOutput)             agent.0.AgentUpdateWorker.0:MainThread       PendingOutputStaging  31.4454  unit.000003   unit  False
# 688      update       unit update pushed (PendingOutputStaging)             agent.0.AgentUpdateWorker.0:MainThread       PendingOutputStaging  31.4454  unit.000003   unit  False
# 710     advance                                                  rp.session.cameo.merzky.016671.0001:OutputFile...              StagingOutput  32.0784  unit.000003   unit  False
# 712     advance                                                  rp.session.cameo.merzky.016671.0001:OutputFile...                       Done  32.0797  unit.000003   unit  False
#
#                     state_from          info
# 7                          NaN     mod_adv_u
# 12                         New     mod_adv_u
# 42                 Unscheduled     mod_adv_u
# 53         PendingInputStaging     mod_adv_u
# 55                StagingInput     mod_adv_u
# 69                         NaN     awo_pub_u
# 70                         NaN     awo_put_u
# 81                         NaN    asic_get_u
# 85                         NaN   asic_work_u
# 86    AgentStagingInputPending    asic_adv_u
# 87                         NaN    asic_pub_u
# 92                         NaN           NaN
# 93                         NaN           NaN
# 94           AgentStagingInput    asic_adv_u
# 95                         NaN    asic_pub_u
# 97                         NaN    asic_put_u
# 98                         NaN           NaN
# 99                         NaN           NaN
# 110                        NaN           NaN
# 125                        NaN     asc_get_u
# 126                        NaN    asc_work_u
# 127          AllocatingPending     asc_adv_u
# 128                        NaN     asc_pub_u
# 133                        NaN           NaN
# 136                        NaN  asc_alloc_ok
# 137                 Allocating     asc_adv_u
# 141                        NaN     asc_pub_u
# 143                        NaN     asc_put_u
# 144                        NaN           NaN
# 201                        NaN           NaN
# 205                        NaN           NaN
# 215                        NaN           NaN
# 216                        NaN           NaN
# 251                        NaN           NaN
# 252                        NaN           NaN
# 253                        NaN           NaN
# 254                        NaN           NaN
# 336                        NaN           NaN
# 343                        NaN           NaN
# 344                        NaN           NaN
# 347                        NaN           NaN
# 348                        NaN           NaN
# 376                        NaN           NaN
# 378                        NaN     aew_get_u
# 379                        NaN    aew_work_u
# 380           ExecutingPending     aew_adv_u
# 381                        NaN     aew_pub_u
# 382                        NaN           NaN
# 383                        NaN           NaN
# 384                        NaN           NaN
# 385                        NaN           NaN
# 386                        NaN           NaN
# 388                        NaN           NaN
# 389                        NaN           NaN
# 390                        NaN     aew_put_u
# 391                        NaN           NaN
# 401                        NaN           NaN
# 492                        NaN           NaN
# 500                        NaN           NaN
# 509                        NaN     aew_get_u
# 510                        NaN           NaN
# 511                  Executing     aew_adv_u
# 512                        NaN     aew_pub_u
# 513                        NaN     aew_put_u
# 514                        NaN           NaN
# 515                        NaN           NaN
# 516                        NaN           NaN
# 518                        NaN           NaN
# 528                        NaN           NaN
# 529                        NaN           NaN
# 530                        NaN           NaN
# 531                        NaN           NaN
# 532                        NaN    asoc_get_u
# 533                        NaN   asoc_work_u
# 534  AgentStagingOutputPending    asoc_adv_u
# 535                        NaN    asoc_pub_u
# 536         AgentStagingOutput    asoc_adv_u
# 537                        NaN    asoc_pub_u
# 538                        NaN           NaN
# 687                        NaN           NaN
# 688                        NaN           NaN
# 710       PendingOutputStaging     mod_adv_u
# 712              StagingOutput     mod_adv_u

# %%
print "columns: %s" % dict(uf.dtypes).keys()
print "infos  : %s" % uf['info'].dropna().unique()
print "names  : %s" % uf['name'].dropna().unique()

uf[uf['info'].isin(['ewo_to_ewa', 'ewa_complete'])]
adv = uf[uf['event'].isin(['advance'])]
adv[adv['uid'].isin(['unit.000001'])]

# uf[uf['uid'].isin(['unit.000001'])]
# Out:
# columns: ['info', 'uid', 'entity', 'state', 'state_from', 'time', 'msg', 'cloned', 'event', 'name']
# infos  : ['mod_adv_u' 'awo_pub_u' 'awo_put_u' 'awo_adv_u' 'asic_get_u' 'asic_work_u'
#  'asic_adv_u' 'asic_pub_u' 'asic_put_u' 'asc_get_u' 'asc_work_u'
#  'asc_adv_u' 'asc_pub_u' 'asc_alloc_ok' 'asc_put_u' 'aew_get_u'
#  'aew_work_u' 'aew_adv_u' 'aew_pub_u' 'aew_put_u' 'asoc_get_u'
#  'asoc_work_u' 'asoc_adv_u' 'asoc_pub_u']
# names  : ['rp.session.cameo.merzky.016671.0001:MainThread'
#  'rp.session.cameo.merzky.016671.0001:Thread-1'
#  'rp.session.cameo.merzky.016671.0001:InputFileTransferWorker-1'
#  'rp.session.cameo.merzky.016671.0001:InputFileTransferWorker-2'
#  'agent.0.AgentWorker.0:MainThread'
#  'agent.0.AgentStagingInputComponent.0:MainThread'
#  'agent.0.AgentUpdateWorker.0:Thread-2'
#  'agent.0.SchedulerContinuous.0:MainThread'
#  'agent.0.AgentUpdateWorker.0:MainThread'
#  'agent.0.AgentStagingOutputComponent.0:MainThread'
#  'agent.0.AgentExecutingWatcher_SHELL.0:MainThread'
#  'agent.0.AgentExecutingWatcher_SHELL.0:Watcher'
#  'agent.0.SchedulerContinuous.0:Thread-2'
#  'rp.session.cameo.merzky.016671.0001:OutputFileTransferWorker-1'
#  'rp.session.cameo.merzky.016671.0001:OutputFileTransferWorker-2']
#        event     msg                                               name                      state     time          uid entity cloned                 state_from        info
# 5    advance  create     rp.session.cameo.merzky.016671.0001:MainThread                        New   1.0087  unit.000001   unit  False                        NaN   mod_adv_u
# 15   advance             rp.session.cameo.merzky.016671.0001:MainThread                Unscheduled   1.0385  unit.000001   unit  False                        New   mod_adv_u
# 45   advance               rp.session.cameo.merzky.016671.0001:Thread-1        PendingInputStaging  20.1890  unit.000001   unit  False                Unscheduled   mod_adv_u
# 58   advance          rp.session.cameo.merzky.016671.0001:InputFileT...               StagingInput  22.0088  unit.000001   unit  False        PendingInputStaging   mod_adv_u
# 59   advance          rp.session.cameo.merzky.016671.0001:InputFileT...   AgentStagingInputPending  22.0098  unit.000001   unit  False               StagingInput   mod_adv_u
# 74   advance                           agent.0.AgentWorker.0:MainThread   AgentStagingInputPending  22.0760  unit.000001   unit  False   AgentStagingInputPending   awo_adv_u
# 115  advance            agent.0.AgentStagingInputComponent.0:MainThread          AgentStagingInput  22.0834  unit.000001   unit  False   AgentStagingInputPending  asic_adv_u
# 121  advance            agent.0.AgentStagingInputComponent.0:MainThread          AllocatingPending  22.0838  unit.000001   unit  False          AgentStagingInput  asic_adv_u
# 180  advance                   agent.0.SchedulerContinuous.0:MainThread                 Allocating  22.0908  unit.000001   unit  False          AllocatingPending   asc_adv_u
# 185  advance                   agent.0.SchedulerContinuous.0:MainThread           ExecutingPending  22.0911  unit.000001   unit  False                 Allocating   asc_adv_u
# 414  advance           agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.4584  unit.000001   unit  False           ExecutingPending   aew_adv_u
# 562  advance              agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.5871  unit.000001   unit  False                  Executing   aew_adv_u
# 576  advance           agent.0.AgentStagingOutputComponent.0:MainThread         AgentStagingOutput  30.5939  unit.000001   unit  False  AgentStagingOutputPending  asoc_adv_u
# 578  advance           agent.0.AgentStagingOutputComponent.0:MainThread       PendingOutputStaging  30.5943  unit.000001   unit  False         AgentStagingOutput  asoc_adv_u
# 714  advance          rp.session.cameo.merzky.016671.0001:OutputFile...              StagingOutput  32.0808  unit.000001   unit  False       PendingOutputStaging   mod_adv_u
# 716  advance          rp.session.cameo.merzky.016671.0001:OutputFile...                       Done  32.0815  unit.000001   unit  False              StagingOutput   mod_adv_u

# %%
exe_filter = {'in'  : [{'state' : 'Executing'}],
              'out' : [{'state' : 'AgentStagingOutputPending'}]}

rpu.add_concurrency(adv, tgt='cc_exe', spec=exe_filter)
rpu.add_states(uf)

adv[np.isfinite(adv['cc_exe'])]
# Out:
# /home/merzky/saga/radical.pilot.prof/ve/lib/python2.7/site-packages/radical/pilot/utils/analysis.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame[tgt] = frame.apply(lambda row: _conc(row, spec), axis=1).cumsum()
# /home/merzky/saga/radical.pilot.prof/ve/lib/python2.7/site-packages/radical/pilot/utils/analysis.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame[tgt] = frame.apply(lambda row: _abs (row[tgt]),  axis=1)
# /home/merzky/saga/radical.pilot.prof/ve/lib/python2.7/site-packages/radical/pilot/utils/analysis.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame[tgt] = frame.apply(lambda row: _time(row[tgt]),  axis=1)
#        event msg                                              name                      state     time          uid entity cloned        state_from       info  cc_exe
# 380  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.2157  unit.000003   unit  False  ExecutingPending  aew_adv_u       1
# 394  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.3351  unit.000006   unit  False  ExecutingPending  aew_adv_u       2
# 414  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.4584  unit.000001   unit  False  ExecutingPending  aew_adv_u       3
# 426  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.5759  unit.000002   unit  False  ExecutingPending  aew_adv_u       4
# 438  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.6935  unit.000007   unit  False  ExecutingPending  aew_adv_u       5
# 450  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.8117  unit.000000   unit  False  ExecutingPending  aew_adv_u       6
# 462  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  27.9280  unit.000004   unit  False  ExecutingPending  aew_adv_u       7
# 474  advance      agent.0.AgentExecutingWatcher_SHELL.0:MainThread                  Executing  28.0508  unit.000005   unit  False  ExecutingPending  aew_adv_u       8
# 511  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.3461  unit.000003   unit  False         Executing  aew_adv_u       7
# 541  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.4694  unit.000006   unit  False         Executing  aew_adv_u       6
# 562  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.5871  unit.000001   unit  False         Executing  aew_adv_u       5
# 583  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.7064  unit.000002   unit  False         Executing  aew_adv_u       4
# 604  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.8262  unit.000007   unit  False         Executing  aew_adv_u       3
# 625  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  30.9396  unit.000000   unit  False         Executing  aew_adv_u       2
# 646  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  31.0634  unit.000004   unit  False         Executing  aew_adv_u       1
# 667  advance         agent.0.AgentExecutingWatcher_SHELL.0:Watcher  AgentStagingOutputPending  31.1757  unit.000005   unit  False         Executing  aew_adv_u       0

# %%
# define a colorscheme we use consistently throughout this notebook
font = {'family' : 'monospace',
        'weight' : 'normal',
        'size'   : 14}
plt.rc('font', **font)

def create_figure(title=None):
    """
    create a plot object and tune its layout to our liking.
    """
    
    fig, ax = plt.subplots(figsize=(10,5))
    if title:
        ax.set_title(title, fontsize=18)
    
    ax.grid(False)

    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.spines['bottom'].set_position(('axes', -0.05))
    ax.spines['left'].set_position(('axes', -0.02))
    ax.xaxis.grid(False)
    ax.yaxis.grid(False)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    
    fig.tight_layout()

    return ax

# %%
ax_ops = create_figure('Number of concurrently executing CUs over time')
labels = list()

sub_adv = adv[np.isfinite(adv['cc_exe'])]
sub_adv.plot(x='time', y='cc_exe', ax=ax_ops)

labels.append(sid)

ax_ops.set_xlabel("time (s)",               fontsize=14)
ax_ops.set_ylabel("number of executin CUs", fontsize=14)

legend(labels, loc='upper left',          fontsize=12)
savefig('exe_concurrency.png', bbox_inches='tight')
savefig('exe_concurrency.pdf', bbox_inches='tight')
